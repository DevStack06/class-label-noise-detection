# %%
import matplotlib.pyplot as plt

# %%
x=[95.3216,94.1520,95.0896,95]
plt.plot(range(len(x)),x)
plt.title("accuracy graph with 10% mislabeling")
plt.xlabel("number")
plt.ylabel("accuracy")
plt.show()

# %%
x=[95.3216,92.9824,94.1520,93.879]
plt.plot(range(len(x)),x)
plt.title("accuracy graph with 20% mislabeling")
plt.xlabel("number")
plt.ylabel("accuracy")
plt.show()

# %%
x=[95.3216,94.1520,93.5672,94.736]
plt.plot(range(len(x)),x)
plt.title("accuracy graph with 30% mislabeling")
plt.xlabel("number")
plt.ylabel("accuracy")
plt.show()

# %%
x=[95.3216,91.8128,94.1520,92.3976]
plt.plot(range(len(x)),x)
plt.title("accuracy graph with 40% mislabeling")
plt.xlabel("number")
plt.ylabel("accuracy")
plt.show()
