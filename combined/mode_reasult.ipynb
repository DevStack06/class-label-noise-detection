# %%
import matplotlib.pyplot as plt

# %%
x=[93.3216,72.09,83.82,88.10]
plt.plot(range(len(x)),x)
plt.title("accuracy graph with 40% mislabeling  for svm dataset A")
plt.xlabel("number")
plt.ylabel("accuracy")
plt.show()

# %%
x=[95.3216,0.9636,0.7208]
plt.plot(range(len(x)),x)
plt.title("accuracy graph with 20% mislabeling for svm dataset A")
plt.xlabel("number")
plt.ylabel("accuracy")
plt.show()

# %%
x=[95.3216,0.87,.79385]
plt.plot(range(len(x)),x)
plt.title("accuracy graph with 30% mislabeling for svm dataset A")
plt.xlabel("number")
plt.ylabel("accuracy")
plt.show()

# %%
x=[95.3216,0.836,0.6508]
plt.plot(range(len(x)),x)
plt.title("accuracy graph with 40% mislabeling for svm dataset A")
plt.xlabel("number")
plt.ylabel("accuracy")
plt.show()
